# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/coddingjatin/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# # My Lane
#
# I chose the **Content Refresh Prioritization** lane.
#
# Many websites contain thousands of pages, but updating every page is expensive and time-consuming. My goal is to identify which pages should be refreshed first so that content teams can focus on the pages most likely to benefit from an update.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# My Lane

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# # Research Question
#
# **Question**
# Can machine learning identify pages that are likely to decline in performance so they can be refreshed before losing significant traffic?
#
# **Unit of Analysis**
# One webpage.
#
# **Output**
# A priority score indicating whether a page should be refreshed.
#
# **Decision**
# Which pages should be updated first.
#
# **Action**
# The SEO or content team refreshes the highest-priority pages.
#
# **Cost of a Wrong Recommendation**
# Missing a declining page can reduce traffic and waste opportunities. Refreshing the wrong page wastes time and effort.
#
# **Why ML?**
# Machine learning can identify patterns across multiple features such as impressions, CTR, content age, and average position better than simple manual rules.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Research Question

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

print("Number of pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 4))
print("Median Word Count:", int(df["word_count"].median()))
print("\nTrend Direction Distribution:")
print(df["trend_direction"].value_counts())

# %% [markdown]
# ### Observations
#
# - The dataset contains thousands of pages.
# - CTR varies across pages, suggesting different levels of user engagement.
# - Pages belong to different trend categories, indicating that predicting declining pages is a meaningful problem.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# # Careful Words
#
# This work is based only on the provided anonymized dataset.
#
# The observations show relationships in this dataset but do not prove how Google's ranking algorithm works.
#
# The final model should be used as a decision-support tool rather than a replacement for human judgment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
## Careful Words

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - ✅ Selected a lane
# - ✅ Defined the decision
# - ✅ Defined the action
# - ✅ Explained the cost of wrong predictions
# - ✅ Included real numbers from the dataset
# - ✅ Used careful language
